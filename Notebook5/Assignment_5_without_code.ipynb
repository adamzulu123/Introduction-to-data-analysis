# %%
import numpy as np
from scipy.stats import norm, expon, chi2, uniform
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Standard distributions sampling
# ## Ex 1.
# Use scipy to take samples from the following distributions:
# 1. Normal distribution with $\mu$=1 and $\sigma$=4,
# 2. Exponential distribution with $\lambda = \dfrac{1}{4}$,
# 3. Chi-squared distribution with 8 degrees of freedom,
# 4. Uniform distribution with borders [$-2\sqrt{3}, 6\sqrt{3}$].
#
# Compare their theoretical and sample distribution, mean and variance.

# %%
#1. Normal
#This one I'll do for you :-)

rv_norm = norm(loc = 1, scale = 4) #1. - zzdefiniowanie rozkładu normalnego 
#rv_norm.pdf(x) - oblicza wartosci gęstosci prawdopodobieństwa 
x = np.linspace(rv_norm.ppf(0.01), rv_norm.ppf(0.99), 100)
fig, ax = plt.subplots(1, 1)
ax.plot(x, rv_norm.pdf(x), 'r-', lw=5, alpha=0.6, label='norm pdf')
r = rv_norm.rvs(size=1000) #generujemy 1000 próbek tego rozkładu 
ax.hist(r, density=True, histtype='stepfilled', alpha=0.2, bins = x[::4])


ax.legend(loc='best', frameon=False)
plt.show()

print("Distribution mean: {0}".format(rv_norm.stats(moments='m'))) #podaje teoretyczną wartość oczekiwaną μ
print("Distribution variance: {0}".format(rv_norm.stats(moments='v'))) #teoretyczną wariancję (σ2)
print("Sample mean: {0}".format(np.mean(r))) #średnia 
print("Sample variance: {0}".format(np.var(r)))#wariacja
# Out:
# Distribution mean: 1.0
# Distribution variance: 16.0
# Sample mean: 0.8981520230777206
# Sample variance: 16.244458236836063

# %%
from matplotlib.pyplot import hist
#Exponential

#definition 
rv_expon = expon(scale=4) # scale = 1/lambda = 4
x = np.linspace(rv_expon.ppf(0.01), rv_expon.ppf(0.99), 100)

fig, ax = plt.subplots(1, 1)
ax.plot(x, rv_expon.pdf(x), 'r-', lw=5, alpha=0.6, label='expon pdf')

r = rv_expon.rvs(size=1000)
ax.hist(r, density=True, histtype='stepfilled', alpha=0.2, bins = x[::4])

ax.legend(loc='best', frameon=False)
plt.show()

print("Distribution mean: {0}".format(rv_expon.stats(moments='m')))
print("Distribution variance: {0}".format(rv_expon.stats(moments='v')))
print("Sample mean: {0}".format(np.mean(r)))
print("Sample variance: {0}".format(np.var(r)))
#hint: expon
# Out:
# Distribution mean: 4.0
# Distribution variance: 16.0
# Sample mean: 4.101947126470152
# Sample variance: 17.098145773743358

# %%
#chi2

rv_chi2 = chi2(df=8)
x = np.linspace(rv_chi2.ppf(0.01), rv_chi2.ppf(0.99), 100)

fig, ax = plt.subplots(1, 1)
ax.plot(x, rv_chi2.pdf(x), 'r-', lw=5, alpha=0.6, label='chi2 pdf')

r = rv_chi2.rvs(size=1000)
ax.hist(r, density=True, histtype='stepfilled', alpha=0.2, bins = x[::4])
ax.legend(loc='best', frameon=False)
plt.show()

print("Distribution mean: {0}".format(rv_chi2.stats(moments='m')))
print("Distribution variance: {0}".format(rv_chi2.stats(moments='v')))
print("Sample mean: {0}".format(np.mean(r)))
print("Sample variance: {0}".format(np.var(r)))

#hint: chi2
# Out:
# Distribution mean: 8.0
# Distribution variance: 16.0
# Sample mean: 7.997312797943345
# Sample variance: 16.097435836407815

# %%
#uniform
#Uniform distribution with borders [$-2\sqrt{3}, 6\sqrt{3}$].

a, b = -2 * np.sqrt(3), 6 * np.sqrt(3)

rv_uniform = uniform(loc=a, scale=b - a)
x = np.linspace(rv_uniform.ppf(0.01), rv_uniform.ppf(0.99), 100)

fig, ax = plt.subplots(1, 1)
ax.plot(x, rv_uniform.pdf(x), 'r-', lw=5, alpha=0.6, label='uniform pdf')

r = rv_uniform.rvs(size=1000)
ax.hist(r, density=True, histtype='stepfilled', alpha=0.2, bins = x[::4])
ax.legend(loc='best', frameon=False)
plt.show()

print("Distribution mean: {0}".format(rv_uniform.stats(moments='m')))
print("Distribution variance: {0}".format(rv_uniform.stats(moments='v')))
print("Sample mean: {0}".format(np.mean(r)))
print("Sample variance: {0}".format(np.var(r)))

#hint: uniform
# Out:
# Distribution mean: 3.4641016151377544
# Distribution variance: 15.999999999999998
# Sample mean: 3.4715891078115217
# Sample variance: 16.347241304687014

# %% [markdown]
# # Low of large numbers. Central Limit Theorem.
# ## Ex 2.
# a) For N from 2 to 1000 draw N samples from distributions defined in Ex 1. Plot sample variance and mean against the size of the sample.

# %%
#here goes your code
X = np.arange(2, 1001)

#preparing data for visualisation 
#normal
rv_norm = norm(loc = 1, scale = 4)
rv_norm_var = [np.var(rv_norm.rvs(size=x)) for x in X] 
rv_norm_mean = [np.mean(rv_norm.rvs(size=x)) for x in X]

#exponential
rv_emp = expon(scale=4)
rv_expon_var = [np.var(rv_expon.rvs(size=x)) for x in X]
rv_expon_mean = [np.mean(rv_expon.rvs(size=x)) for x in X]

#chi2
rv_chi2 = chi2(df=8)
rv_chi_var = [np.var(rv_chi2.rvs(size=x)) for x in X]
rv_chi_mean = [np.mean(rv_chi2.rvs(size=x)) for x in X]

#uniform 
a, b = -2 * np.sqrt(3), 6 * np.sqrt(3)
rv_uniform = uniform(loc=a, scale=b - a)
rv_uniform_var = [np.var(rv_uniform.rvs(size=x)) for x in X]
rv_uniform_mean = [np.mean(rv_uniform.rvs(size=x)) for x in X]

#PLOTS 
#variances 
plt.figure(figsize=(12, 10))

plt.subplot(2, 2, 1)
plt.plot(X, rv_norm_var, color="green")
# rv_norm.stats(moments='v') - zwraca statystyki rozkładu 'v' oznacza wariacje rozkładu 
plt.axhline(rv_norm.stats(moments='v'), color="red", linestyle="--", label="Theoretical variance")
plt.title("Normal ")
plt.xlabel("Sample Size")
plt.ylabel("Variance")
plt.legend()
plt.grid()

plt.subplot(2, 2, 2)
plt.plot(X, rv_expon_var, color="green")
plt.axhline(rv_expon.stats(moments='v'), color="red", linestyle="--", label="Theoretical variance")
plt.title("Exponential ")
plt.xlabel("Sample Size")
plt.ylabel("Variance")
plt.legend()
plt.grid()

plt.subplot(2, 2, 3)
plt.plot(X, rv_chi_var, color="green")
plt.axhline(rv_chi2.stats(moments='v'), color="red", linestyle="--", label="Theoretical variance")
plt.title("Chi2")
plt.xlabel("Sample Size")
plt.ylabel("Variance")
plt.legend()
plt.grid()

plt.subplot(2, 2, 4)
plt.plot(X, rv_uniform_var, color="green")
plt.axhline(rv_uniform.stats(moments='v'), color="red", linestyle="--", label="Theoretical variance")
plt.title("Uniform")
plt.xlabel("Sample Size")
plt.ylabel("Variance")
plt.legend()
plt.grid()



#means
plt.figure(figsize=(12, 10))

plt.subplot(2, 2, 1)
plt.plot(X, rv_norm_mean)
plt.axhline(rv_norm.stats(moments='m'), color="red", linestyle="--", label="Theoretical mean")
plt.title("Normal")
plt.xlabel("Sample Size")
plt.ylabel("Mean")
plt.legend()
plt.grid()

plt.subplot(2, 2, 2)
plt.plot(X, rv_expon_mean)
plt.axhline(rv_expon.stats(moments='m'), color="red", linestyle="--", label="Theoretical mean")
plt.title("Exponential ")
plt.xlabel("Sample Size")
plt.ylabel("Mean")
plt.legend()
plt.grid()

plt.subplot(2, 2, 3)
plt.plot(X, rv_chi_mean)
plt.axhline(rv_chi2.stats(moments='m'), color="red", linestyle="--", label="Theoretical mean")
plt.title("Chi2")
plt.xlabel("Sample Size")
plt.ylabel("Variance")
plt.legend()
plt.grid()

plt.subplot(2, 2, 4)
plt.plot(X, rv_uniform_mean)
plt.axhline(rv_uniform.stats(moments='m'), color="red", linestyle="--", label="Theoretical mean")
plt.title("Uniform")
plt.xlabel("Sample Size")
plt.ylabel("Variance")
plt.legend()
plt.grid()


plt.show()

# %% [markdown]
# #### Results
# These plots demonstrate that as the sample size increases, both the sample mean and variance converge to their theoretical values. The larger the sample, the more accurate the estimates of the population parameters become.

# %% [markdown]
# ## Ex 3.
# For N=1,4,9,16 draw histograms of an average over N samples taken from distributions defined in Ex 1.

# %%
N = [1,4,9,16]

plt.figure(figsize=(12, 15))

plt.subplot(4, 1, 1)
plt.title("Averaged normal distribution")
for n in N: 
    rv_norm_dis = np.mean(rv_norm.rvs(size=(n, 1000)), axis=0)
    plt.hist(rv_norm_dis, density=True, histtype='stepfilled', alpha=0.4, bins = 25, label=f"{n} samples")
plt.legend()

plt.subplot(4, 1, 2)
plt.title("Averaged exponential distribution")
for n in N: 
    rv_expon_dis = np.mean(rv_expon.rvs(size=(n, 1000)), axis=0)
    plt.hist(rv_expon_dis,density=True, histtype='stepfilled', alpha=0.4, bins = 25, label=f"{n} samples")
plt.legend()

plt.subplot(4, 1, 3)
plt.title("Averaged Chi2 distribution")
for n in N:
    rv_chi2_dis = np.mean(rv_chi2.rvs(size=(n, 1000)), axis=0)
    plt.hist(rv_chi2_dis,density=True, histtype='stepfilled', alpha=0.4, bins = 25, label=f"{n} samples")
plt.legend()

plt.subplot(4, 1, 4)
plt.title("Averaged Uniform distribution")
for n in N:
    rv_uniform_dis = np.mean(rv_uniform.rvs(size=(n, 1000)), axis=0)
    plt.hist(rv_uniform_dis,density=True, histtype='stepfilled', alpha=0.4, bins = 25, label=f"{n} samples")
plt.legend()

plt.subplots_adjust(hspace=0.5) #space between plots 

plt.show()

# %% [markdown]
# #### Results
#  The histograms demonstrate how the sample means for N = [1, 4, 9, 16] from various distributions increasingly resemble a normal distribution, regardless of the original distribution.
# For any distribution with finite variance, the means of the samples will converge to a normal distribution as the sample size (\(N\)) increases.
# The larger samle size, the more symmetric and narrow the histogram becomes!

# %% [markdown]
# # Arbitrary distribution sampling
#
# Sometimes it may happen, that we need to sample from a custom distribution, not implemented in any standard library. There exist a simple algorithm for such sampling, provided that the distribution is bounded (pdf has finite support and maximum).
#
#
# #### Accept-rejection sampling
# Let the distribution be given by the pdf $g(x)$ and defined at interval $[a,b]$. In addition, let $M$ be the supremum of $g(x)$.
#
# 1. Take a sample $t$ from the uniform distribution at the interval $[a,b]$,
# 2. Take a sample $u$ from the uniform distribution at the interval $[0,M]$,
# 3. If $g(t) > u$ we accept $t$ as a sample taken from the original distribution. If not, we go back to 1.
#
# ## Ex 4.
# Implement function accept_rejection_sampling(dist, size = 1) which samples from any bounded distribution on the [0,1] interval.

# %%
def toy_dist(x):
    C = 1/3 - np.exp(-4)/4 + 1/4
    return (x**2 + np.exp(-4*x)) / C 

x = np.linspace(0,1,1000)

def accept_rejection_sampling(dist, size = 1):
    samples = []
    M = max(dist)  #maksymalna wartość funkcji gęstości
    
    while len(samples) < size:
        t = np.random.uniform(a, b)  #a,b - przedział dystrybucji 
        u = np.random.uniform(0, M)  #losowanie z rozkładu jednostajnego [0, M] 
        
        if toy_dist(t) > u: #warunek akceptacji 
            samples.append(t)
    
    return samples

samples = accept_rejection_sampling(toy_dist(x), size = 10000)

fig, ax = plt.subplots(1, 1)
ax.plot(x, toy_dist(x), 'r-', lw=5, alpha=0.6, label='toy pdf')
ax.hist(samples, density=True, histtype='stepfilled', alpha=0.2, bins = x[::40], label = "sampled")
ax.legend(loc='best', frameon=False)
plt.show()

# %% [markdown]
# # Probability space matters!
# ## Ex 5
# Sample 2000 points from the unit disk. Do it in following ways:
# 1. Assume uniform distribution of radius (0,1) and argument (0,2$\pi$),
# 2. Assume uniform distribution of x and y coordinate (-1,1). Drop values laying outside of the disk.
# Explain differences. between 1. and 2. Then:
# 3. Modify the solution of point 1. by changing the distribution of the radius in such a way, that we result in 2D distribution from 2.

# %%
import math

#Version1
rv_uni_r = uniform(0, 1)
rv_uni_arg = uniform(0, 2*math.pi*math.pi)

r_points = rv_uni_r.rvs(size=2000)
arg_points = rv_uni_arg.rvs(size=2000)

plt.figure(figsize=(12, 4))

plt.subplot(1, 3, 1)
plt.scatter((r_points * np.sin(arg_points)), (r_points * np.cos(arg_points)), alpha=0.2, s=7)
plt.xlabel("x")
plt.ylabel("y")

plt.subplot(1, 3, 2)
plt.hist(arg_points, density=True, histtype='stepfilled', alpha=0.2, bins = 30)
plt.xlabel("arg")
plt.ylabel("counts")

plt.subplot(1, 3, 3)
plt.hist(r_points, density=True, histtype='stepfilled', alpha=0.2, bins = 30)
plt.xlabel("r")
plt.ylabel("counts")

plt.subplots_adjust(wspace=0.3)
plt.show()


#Version2
rv_uni = uniform(-1, scale=2)
x_points = rv_uni.rvs(2000)
y_points = rv_uni.rvs(2000)

#droping points outside the unit disk (x^2 + y^2 <= 1)
mask = x_points**2 + y_points**2 <= 1
x_points = x_points[mask]
y_points = y_points[mask]

plt.figure(figsize=(12, 4))

plt.subplot(1, 3, 1)
plt.scatter(x_points, y_points, alpha=0.2, s=7)
plt.xlabel("x")
plt.ylabel("y")

plt.subplot(1, 3, 2)
plt.hist(x_points, density=True, histtype='stepfilled', alpha=0.2, bins=30)
plt.xlabel("x")
plt.ylabel("counts")

plt.subplot(1, 3, 3)
plt.hist(y_points, density=True, histtype='stepfilled', alpha=0.2, bins=30)
plt.xlabel("y")
plt.ylabel("counts")

plt.subplots_adjust(wspace=0.3)
plt.show()

#here goes your code

# %% [markdown]
# #### Comparison
# Comparing both versions, we can see that in the first one, points are concentrated more towards the center of the circle, and the number of samples is larger. This happens because we are generating points using polar coordinates, where the points are denser near the center of the circle. In the second version, we generate points on a square and then filter out those outside the circle, which results in a more uniform distribution of points. However, the number of samples is smaller in this case

# %%
#Version3
# Modify the solution of point 1. by changing the distribution of the radius in such a way, that we result in 2D distribution from 2.

#losujemy z rozkładu jednostajengo - pkt generowane równomieranie na powierzchni dysku 
rv_uni_squared = uniform(0, 1).rvs(2000) 
r_points = np.sqrt(rv_uni_squared) #po wylosowaniu r^2  - obliczamy pierwiastek aby dotac promien z odpowienim rozkladnem 
arg_points = uniform(0, 2*math.pi).rvs(2000) #równomierne rozmieszczenie pkt na okręgu 

plt.figure(figsize=(12, 4))

plt.subplot(1, 3, 1)
plt.scatter((r_points * np.sin(arg_points)), (r_points * np.cos(arg_points)), alpha=0.2, s=7)
plt.xlabel("x")
plt.ylabel("y")

plt.subplot(1, 3, 2)
plt.hist(arg_points, density=True, histtype='stepfilled', alpha=0.2, bins = 30)
plt.xlabel("arg")
plt.ylabel("counts")

plt.subplot(1, 3, 3)
plt.hist(r_points, density=True, histtype='stepfilled', alpha=0.2, bins = 30)
plt.xlabel("r")
plt.ylabel("counts")

plt.subplots_adjust(wspace=0.3)
plt.show()

# %% [markdown]
# ## Application: Laplace equation, Dirichlet boundary conditions
#
# #### Monte-Carlo procedure for solving 2D Laplace equation with Dirichlet boundary conditions
# 1. Start in a random position inside the boundaries,
# 2. With an equal probability move up/down/right/left until you hit the boundary,
# 3. After hitting the boundary we take the value $v_{b}$ of the function in the hitting point. We update the values of all points along the just finished random walk using the formula:
# $$ v_{new} = \dfrac{nv_{old} + v_{b}}{n+1}, $$
# where $n$ is a number of random walks which have already passed through this point.
# 4. Finish if the desired precision is achieved. If not, go back to 1.
#
#
# A theory behind the above procedure can be found here:
# https://www.uzh.ch/cmsssl/physik/dam/jcr:d559688c-1e7f-44ca-9fbe-aab0755c0b6e/empp18_MC_Markov.pdf

# %% [markdown]
# ## Ex 6
# Implement the method described above and solve numerically given Dirichlet problem. Plot few intermediate steps.

# %%
import numpy as np
import matplotlib.pyplot as plt
import random
from scipy.stats import norm, expon, chi2, uniform
# %matplotlib inline

# %%
S = 100 # Decrease if computations take too long
plane = np.zeros((S,S))
plane_counts = np.zeros((S,S))

#boundary conditions 
plane[0] = np.cos(np.linspace(-1.5,1.5,S)*2*np.pi)
plane[-1] = -np.cos(np.linspace(-1,1,S)*2*np.pi)
plane[:,0] = np.cos(np.linspace(-0.5,0.5,S)*2*np.pi)
plane[:,-1] = -2+np.linspace(-1,1,S)**2

# %%
plt.figure(figsize=(10,15))
plt.title("0 walks")
plt.imshow(plane)

# %%
#here goes your code

# %%
#if point is on the boundary 
def is_on_boundary(x, y, S):
    return x == 0 or x == S-1 or y == 0 or y == S-1

def monte_carlo_walks(plane, plane_counts, steps, S):
    for _ in range(steps):
        path = [] 
        #Random starting point inside the grid 
        x, y = np.random.randint(1, S-1), np.random.randint(1, S-1)
        
        #walking in random direction util hitting the boundary 
        while not is_on_boundary(x, y, S):
            path.append((x, y))
            move = np.random.choice(["u", "d", "l", "r"])
            if move == "u": x -= 1
            elif move == "d": x += 1
            elif move == "l": y -= 1
            elif move == "r": y += 1
        
        #get boundary value 
        boundary_value = plane[x, y]
        
        #update the values for all points along the path
        for px, py in path:
            n = plane_counts[px, py]
            plane[px, py] = (n * plane[px, py] + boundary_value) / (n + 1)
            plane_counts[px, py] += 1

#visualisation
S = 100
steps_vis = [0, 5, 38, 110, 316, 913, 2616, 7491, 20553]

fig, axes = plt.subplots(3, 3, figsize=(15, 15))
axes = axes.flatten()

for i, steps in enumerate(steps_vis):
    #resetting conditions for every steps value
    plane = np.zeros((S, S))      
    plane_counts = np.zeros((S, S))  
    plane[0, :] = np.cos(np.linspace(-1.5, 1.5, S) * 2 * np.pi)   
    plane[-1, :] = -np.cos(np.linspace(-1, 1, S) * 2 * np.pi)     
    plane[:, 0] = np.cos(np.linspace(-0.5, 0.5, S) * 2 * np.pi)  
    plane[:, -1] = -2 + np.linspace(-1, 1, S)**2                
    
    #performing walk 
    monte_carlo_walks(plane, plane_counts, steps, S)
    
    #plots 
    ax = axes[i]
    ax.imshow(plane, cmap='viridis', origin='lower')
    ax.set_title(f"{steps} walks")
    ax.axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# On the plots above we can observe solution of the 2D Laplace equation using the Monte Carlo method with Dirichlet boundary conditions.
#
# We can see that with the increasing number of steps the solution becomes more and more clear. In the beginning it is chaotic and imprecise, later ss the number of walks increases, the potential distribution becomes smoother and approaches the analytical solution of the Laplace equation. And with 20553 walks, the potential field becomes almost perfectly continuous and smooth, demonstrating the convergence of the method.

# %%
#Animation code for testing purposes. May not work on your machine.

# %matplotlib qt

import matplotlib.animation as animation 
S = 100 # Decrease if computations take too long
plane = np.zeros((S,S))
plane_counts = np.zeros((S,S))

#boundary conditions 
plane[0] = np.cos(np.linspace(-1.5,1.5,S)*2*np.pi)
plane[-1] = -np.cos(np.linspace(-1,1,S)*2*np.pi)
plane[:,0] = np.cos(np.linspace(-0.5,0.5,S)*2*np.pi)
plane[:,-1] = -2+np.linspace(-1,1,S)**2

planes = [np.copy(plane)] #lista do przechowywania kroków animacji (różnych stanów siatki) 
walks = [0] #lista liczby wykonanych kroków 

# function to update figure
def updatefig(j):
    # set the data in the axesimage object
    steps_per_frame = 100
    monte_carlo_walks(plane, plane_counts, steps_per_frame, S)
    planes.append(np.copy(plane))#dodajemy nowy stan do listy 
    walks.append(walks[-1] + steps_per_frame) #zwiekszamy liczbe kroków 
    
    im.set_array(planes[j])
    plt.title("{0} walks".format(walks[j]))
    return [im]

fig = plt.figure()
plt.title("0 walks")
im = plt.imshow(planes[0], cmap='viridis', origin='lower')

# kick off the animation 
ani = animation.FuncAnimation(fig, updatefig, frames=range(100), interval=1000)
plt.show()

# %% [markdown]
# Animation is just a prettier version of plots above, because we can see how the field is changing in time then on the plots above we can observe only few crucial moments.
